# %%
from obspy import read
import os

# Mac
dirpath =  '/Volumes/classdata/Pinatubo/WAVEFORMS/199112'
filepath = os.path.join(dirpath, '9112010B.DMX')

os.listdir(dirpath)
st = read(filepath)
# Windows
#st = read('Z:/Pinatubo/WAVEFORMS/199112/9112010B.DMX')

print(st)
st.plot();
# Out:
# 7 Trace(s) in Stream:
# unk.CABZ.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples
# unk.QADZ.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples
# unk.PI2Z.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples
# unk.CRWZ.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples
# unk.FNGZ.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples
# unk.CABN.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples
# unk.BUGZ.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples

# %%
from obspy import read
import platform
from pathlib import Path

from set_samba_data_root import DATA_ROOT

# Build file path
filepath = DATA_ROOT / "Pinatubo" / "WAVEFORMS" / "199112" / "9112010B.DMX"

print(f"Reading file from: {filepath}")

# Read waveform
st = read(str(filepath))

print(st)
st.plot();
# Out:
# Reading file from: /Volumes/classdata/Pinatubo/WAVEFORMS/199112/9112010B.DMX
# 7 Trace(s) in Stream:
# unk.CABZ.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples
# unk.QADZ.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples
# unk.PI2Z.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples
# unk.CRWZ.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples
# unk.FNGZ.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples
# unk.CABN.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples
# unk.BUGZ.._ | 1991-12-01T15:29:21.576000Z - 1991-12-01T15:30:32.672641Z | 100.8 Hz, 7168 samples
