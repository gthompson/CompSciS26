# %% [markdown]
# # Antelope Real Time System (ARTS)
# Antelope has several "canned" real-time demos. I like the one for the Global Seismographic Network (GSN).

# %% [markdown]
# On MacOS:
# * Install Antelope
# * Install Xquartz
# * Start a Terminal from XQuartz
# * source /opt/antelope/5.15/setup.sh
# * rtdemo
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
