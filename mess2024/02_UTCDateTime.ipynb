# %% [markdown]
# <div style='background-image: url("../share/images/header.svg") ; padding: 0px ; background-size: cover ; border-radius: 5px ; height: 250px'>
#     <div style="float: right ; margin: 50px ; padding: 20px ; background: rgba(255 , 255 , 255 , 0.7) ; width: 50% ; height: 150px">
#         <div style="position: relative ; top: 50% ; transform: translatey(-50%)">
#             <div style="font-size: xx-large ; font-weight: 900 ; color: rgba(0 , 0 , 0 , 0.8) ; line-height: 100%">ObsPy Tutorial</div>
#             <div style="font-size: large ; padding-top: 20px ; color: rgba(0 , 0 , 0 , 0.5)">Handling Time</div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# Seismo-Live: http://seismo-live.org
#
# ##### Authors:
# * Lion Krischer ([@krischer](https://github.com/krischer))
# * Tobias Megies ([@megies](https://github.com/megies))
# ---

# %% [markdown]
# ![](images/obspy_logo_full_524x179px.png)

# %% [markdown]
# This is a bit dry but not very difficult and important to know. It is used everywhere in ObsPy!
#
#
# * All absolute time values are consistently handled with this class
# * Based on a double precision POSIX timestamp for accuracy
# * Timezone can be specified at initialization (if necessary)
# * In Coordinated Universal Time (UTC) so no need to deal with timezones, daylight savings, ...
#
# ---

# %%
from __future__ import print_function

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ---
#
# ## Features of **`UTCDateTime`**
#
# #### Initialization

# %%
from obspy import UTCDateTime
print(UTCDateTime("2011-03-11T05:46:23.2"))        # mostly time strings defined by ISO standard
print(UTCDateTime("2011-03-11T14:46:23.2+09:00"))  # non-UTC timezone input
print(UTCDateTime(2011, 3, 11, 5, 46, 23, 2))
print(UTCDateTime(1299822383.2))
# Out:
# 2011-03-11T05:46:23.200000Z
# 2011-03-11T05:46:23.200000Z
# 2011-03-11T05:46:23.000002Z
# 2011-03-11T05:46:23.200000Z

# %%
# Current time can be initialized by leaving out any arguments
print(UTCDateTime())
# Out:
# 2026-02-12T16:24:09.819342Z

# %% [markdown]
# #### Attribute Access

# %%
time = UTCDateTime("2011-03-11T05:46:23.200000Z")
print(time.year)
print(time.julday)
print(time.timestamp)
print(time.weekday)
# try time.<Tab>
time.second=0
print(time)
# Out:
# 2011
# 70
# 1299822383.2
# 4
# 2011-03-11T05:46:00.200000Z
# /Users/thompsong/miniconda3/envs/compsci/lib/python3.11/site-packages/obspy/core/utcdatetime.py:1264: ObsPyDeprecationWarning: Setting attributes on UTCDateTime instances will raise an Exception in a future version of Obspy.
#   warnings.warn(msg, ObsPyDeprecationWarning)

# %% [markdown]
# #### Handling time differences
#
# * "**`+`**/**`-`**" defined to add seconds to an **`UTCDateTime`** object
# * "**`-`**" defined to get time difference of two **`UTCDateTime`** objects

# %%
time = UTCDateTime("2011-03-11T05:46:23.200000Z")
print(time)
# Out:
# 2011-03-11T05:46:23.200000Z

# %%
# one hour later
print(time + 3600)
# Out:
# 2011-03-11T06:46:23.200000Z

# %%
time2 = UTCDateTime(2012, 1, 1)
secondsPerDay = 60 * 60 * 24
print((time2 - time)/secondsPerDay)
# Out:
# 295.75971990740743

# %% [markdown]
# ### Exercises
#
# Calculate the number of days passed since the Tohoku main shock (the timestamp used above).

# %%
timenow = UTCDateTime.now() 
print((timenow - time)/secondsPerDay)
# Out:
# 5452.452742796944

# %% [markdown]
# Make a list of 10 UTCDateTime objects, starting today at 10:00 with a spacing of 90 minutes.

# %%
t = UTCDateTime(2026, 2, 12, 10, 0, 0)
t = UTCDateTime().replace(hour=10, minute=0, second=0, microsecond=0)

times = []
ninetyMinutes = 90 * 60
for i in range(10):
    t2 = t + i * ninetyMinutes
    times.append(t2)

print(times)
# Out:
# [UTCDateTime(2026, 2, 12, 10, 0), UTCDateTime(2026, 2, 12, 11, 30), UTCDateTime(2026, 2, 12, 13, 0), UTCDateTime(2026, 2, 12, 14, 30), UTCDateTime(2026, 2, 12, 16, 0), UTCDateTime(2026, 2, 12, 17, 30), UTCDateTime(2026, 2, 12, 19, 0), UTCDateTime(2026, 2, 12, 20, 30), UTCDateTime(2026, 2, 12, 22, 0), UTCDateTime(2026, 2, 12, 23, 30)]

# %%
from obspy import UTCDateTime

t = UTCDateTime(2014, 2, 24, 10)

times = [t + i * 90 * 60 for i in range(10)]

times
# Out:
# [2014-02-24T10:00:00.000000Z,
#  2014-02-24T11:30:00.000000Z,
#  2014-02-24T13:00:00.000000Z,
#  2014-02-24T14:30:00.000000Z,
#  2014-02-24T16:00:00.000000Z,
#  2014-02-24T17:30:00.000000Z,
#  2014-02-24T19:00:00.000000Z,
#  2014-02-24T20:30:00.000000Z,
#  2014-02-24T22:00:00.000000Z,
#  2014-02-24T23:30:00.000000Z]

# %% [markdown]
# Below is a list of strings with origin times of magnitude 8+ earthquakes since 2000 (fetched from IRIS). Assemble a list of interevent times in days. Use matplotlib to display a histogram.

# %%
times = ["2001-06-23T20:33:09",
         "2003-09-25T19:50:07",
         "2004-12-23T14:59:00",
         "2004-12-26T00:58:52",
         "2005-03-28T16:09:35",
         "2006-06-01T18:57:02",
         "2006-06-05T00:50:31",
         "2006-11-15T11:14:14",
         "2007-01-13T04:23:23",
         "2007-04-01T20:39:56",
         "2007-08-15T23:40:58",
         "2007-09-12T11:10:26",
         "2009-09-29T17:48:11",
         "2010-02-27T06:34:13",
         "2011-03-11T05:46:23",
         "2012-04-11T08:38:36",
         "2012-04-11T10:43:10",
         "2013-05-24T05:44:48"]
utcdt = UTCDateTime(times)
utcdt = [UTCDateTime(t) for t in times]
print(utcdt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 19
#       1 times = ["2001-06-23T20:33:09",
#       2          "2003-09-25T19:50:07",
#       3          "2004-12-23T14:59:00",
#    (...)     17          "2012-04-11T10:43:10",
#      18          "2013-05-24T05:44:48"]
# ---> 19 utcdt = UTCDateTime(times)
#      20 utcdt = [UTCDateTime(t) for t in times]
#      21 print(utcdt)
#
# File ~/miniconda3/envs/compsci/lib/python3.11/site-packages/obspy/core/utcdatetime.py:452, in UTCDateTime.__init__(self, *args, **kwargs)
#     449     args = args[0:5]
#     451 try:  # If a value Error is raised try to allow overflow (see #2222)
# --> 452     dt = datetime.datetime(*args, **kwargs)
#     453 except ValueError:
#     454     if not strict:
#
# TypeError: 'list' object cannot be interpreted as an integer
