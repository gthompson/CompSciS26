# %%
import sys
from pathlib import Path

from obspy import UTCDateTime
from flovopy.research.mvo.archive import MVOSeisanArchive
from flovopy.enhanced.sdsclient import EnhancedSDSClient

# -----------------------------------------------------------------------------
# Local path setup
# -----------------------------------------------------------------------------
sys.path.append("../week8")  # this is where set_samba_data_root.py lives
from set_samba_data_root import DATA_ROOT  # noqa: E402

MVO_ROOT = Path(DATA_ROOT) / "SEISAN_DB"   # root of the MVO Seisan archive
mvo = MVOSeisanArchive(MVO_ROOT)

sds_root = Path("~/work/SDS").expanduser()
sds_root.mkdir(parents=True, exist_ok=True)
client = EnhancedSDSClient(str(sds_root))

# -----------------------------------------------------------------------------
# Time range to convert: one UTC day at a time
# -----------------------------------------------------------------------------
start_day = UTCDateTime(2003, 7, 1, 0, 0, 0)   # inclusive
end_day   = UTCDateTime(2003, 7, 14, 0, 0, 0)   # exclusive

# -----------------------------------------------------------------------------
# Conversion loop
# -----------------------------------------------------------------------------
day_start = start_day
all_written = []

while day_start < end_day:
    day_end = day_start + 86400  # 1 day

    print("=" * 80)
    print(f"Reading day: {day_start.date}  ({day_start} to {day_end})")

    st = mvo.read_continuous_stream(
        day_start,
        day_end,
        verbose=True,
        seismic_only=True,
        vertical_only=True,
        merge=True,          # use smart_merge during read
    )

    print(st)

    if len(st) == 0:
        print("No data found for this day.")
        day_start = day_end
        continue

    written = client.write_stream(
        st,
        #mode="merge",        # merge with any SDS files already written
        preprocess=False,    # stream already merged/read the way you want
        verbose=True,
        reclen=4096,
        # do not force encoding; let ObsPy choose
    )

    print(f"Wrote {len(written)} SDS files for {day_start.date}")
    for p in written[:10]:
        print("  ", p)

    all_written.extend(written)
    day_start = day_end

print("=" * 80)
print(f"Total SDS files written: {len(all_written)}")
print(f"SDS root: {sds_root}")
# Out:
# ================================================================================
# Reading day: 2003-07-01  (2003-07-01T00:00:00.000000Z to 2003-07-02T00:00:00.000000Z)
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Fixing MVO trace ID: .MBRY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBRY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# Overriding conflicting orientation for MBRY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBSS.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBSS with Fs=75.0
# Fixing MVO trace ID: .MBLG.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBLG with Fs=75.0
# Fixing MVO trace ID: .MBLG.S.AP legacy=False short_period=False
# Handling microbarometer channel: AP at MBLG with Fs=75.0
# Converted microbarometer channel: S.BDO
# Fixing MVO trace ID: .MBGB.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Fixing MVO trace ID: .MBGB.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGB.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGB with Fs=75.0
# Overriding conflicting orientation for MBGB: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBRV.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBRV with Fs=75.0
# Fixing MVO trace ID: .MBGH.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Fixing MVO trace ID: .MBGH.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBGH.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBGH with Fs=75.0
# Overriding conflicting orientation for MBGH: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBLY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Fixing MVO trace ID: .MBLY.N.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='N'
# Fixing MVO trace ID: .MBLY.E.BH legacy=False short_period=False
# Handling seismic channel: BH at MBLY with Fs=100.0
# Overriding conflicting orientation for MBLY: channel='BH' gives 'Z', location='E'
# Fixing MVO trace ID: .MBWH.Z.SH legacy=False short_period=False
# Handling seismic channel: SH at MBWH with Fs=75.0
# Fixing MVO trace ID: .MBRY.Z.BH legacy=False short_period=False
# Handling seismic channel: BH at MBRY with Fs=75.0
# ...
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Fixing MVO trace ID: MV.MBWH..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBWH with Fs=75.0
# Fixing MVO trace ID: MV.MBRY..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBRY with Fs=75.0
# Fixing MVO trace ID: MV.MBSS..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBSS with Fs=75.0
# Fixing MVO trace ID: MV.MBLG..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBLG with Fs=75.0
# Fixing MVO trace ID: MV.MBGB..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGB with Fs=75.0
# Fixing MVO trace ID: MV.MBRV..SHZ legacy=False short_period=False
# Handling seismic channel: SHZ at MBRV with Fs=75.0
# Fixing MVO trace ID: MV.MBGH..BHZ legacy=False short_period=False
# Handling seismic channel: BHZ at MBGH with Fs=75.0
# Fixing MVO trace ID: MV.MBLY..HHZ legacy=False short_period=False
# Handling seismic channel: HHZ at MBLY with Fs=100.0
# Merging MV.MBWH..SHZ: 71 traces
# Merging MV.MBRY..BHZ: 71 traces
# Merging MV.MBSS..SHZ: 71 traces
# Merging MV.MBLG..SHZ: 71 traces
# Merging MV.MBGB..BHZ: 71 traces
# Merging MV.MBRV..SHZ: 71 traces
# Merging MV.MBGH..BHZ: 71 traces
# Merging MV.MBLY..HHZ: 68 traces
# 8 Trace(s) in Stream:
# MV.MBWH..SHZ | 2003-07-13T00:00:00.000000Z - 2003-07-13T23:59:59.986667Z | 75.0 Hz, 6480000 samples (masked)
# MV.MBRY..BHZ | 2003-07-13T00:00:00.000000Z - 2003-07-13T23:59:59.986667Z | 75.0 Hz, 6480000 samples (masked)
# MV.MBSS..SHZ | 2003-07-13T00:00:00.000000Z - 2003-07-13T23:59:59.986667Z | 75.0 Hz, 6480000 samples (masked)
# MV.MBLG..SHZ | 2003-07-13T00:00:00.000000Z - 2003-07-13T23:59:59.986667Z | 75.0 Hz, 6480000 samples (masked)
# MV.MBGB..BHZ | 2003-07-13T00:00:00.000000Z - 2003-07-13T23:59:59.986667Z | 75.0 Hz, 6480000 samples (masked)
# MV.MBRV..SHZ | 2003-07-13T00:00:00.000000Z - 2003-07-13T23:59:59.986667Z | 75.0 Hz, 6480000 samples (masked)
# MV.MBGH..BHZ | 2003-07-13T00:00:00.000000Z - 2003-07-13T23:59:59.986667Z | 75.0 Hz, 6480000 samples (masked)
# MV.MBLY..HHZ | 2003-07-13T00:00:00.000000Z - 2003-07-13T23:59:59.990000Z | 100.0 Hz, 8640000 samples (masked)
# Wrote 8 SDS files for 2003-07-13
#    /Users/glennthompson/work/SDS/2003/MV/MBWH/SHZ.D/MV.MBWH.--.SHZ.D.2003.194
#    /Users/glennthompson/work/SDS/2003/MV/MBRY/BHZ.D/MV.MBRY.--.BHZ.D.2003.194
#    /Users/glennthompson/work/SDS/2003/MV/MBSS/SHZ.D/MV.MBSS.--.SHZ.D.2003.194
#    /Users/glennthompson/work/SDS/2003/MV/MBLG/SHZ.D/MV.MBLG.--.SHZ.D.2003.194
#    /Users/glennthompson/work/SDS/2003/MV/MBGB/BHZ.D/MV.MBGB.--.BHZ.D.2003.194
#    /Users/glennthompson/work/SDS/2003/MV/MBRV/SHZ.D/MV.MBRV.--.SHZ.D.2003.194
#    /Users/glennthompson/work/SDS/2003/MV/MBGH/BHZ.D/MV.MBGH.--.BHZ.D.2003.194
#    /Users/glennthompson/work/SDS/2003/MV/MBLY/HHZ.D/MV.MBLY.--.HHZ.D.2003.194
# ================================================================================
# Total SDS files written: 100
# SDS root: /Users/glennthompson/work/SDS
